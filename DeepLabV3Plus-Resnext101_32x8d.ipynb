# %%
import os
import torch
import numpy as np
import cv2
import json
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
import albumentations as A
from albumentations.pytorch import ToTensorV2
import segmentation_models_pytorch as smp
import pytorch_lightning as pl
from torchmetrics.classification import BinaryJaccardIndex
from pytorch_lightning.callbacks import EarlyStopping, ModelCheckpoint, LearningRateMonitor

torch.set_float32_matmul_precision('high')


# -------------------------------
# Dataset
# -------------------------------

class INRIA_Dataset(Dataset):
    def __init__(self, image_dir, mask_dir, transforms=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transforms = transforms
        self.images = sorted(os.listdir(image_dir))
        self.masks = sorted(os.listdir(mask_dir))

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.images[idx])
        mask_path = os.path.join(self.mask_dir, self.masks[idx])

        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = (mask > 127).astype('float32')

        if self.transforms:
            augmented = self.transforms(image=image, mask=mask)
            image = augmented['image']
            mask = augmented['mask'].unsqueeze(0)  # (1, H, W)

        return image, mask

def get_train_transforms():
    return A.Compose([
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.RandomRotate90(p=0.5),
        A.Normalize(mean=(0.485, 0.456, 0.406),
                    std=(0.229, 0.224, 0.225)),
        ToTensorV2()
    ])

def get_val_transforms():
    return A.Compose([
        A.Normalize(mean=(0.485, 0.456, 0.406),
                    std=(0.229, 0.224, 0.225)),
        ToTensorV2()
    ])

# -------------------------------
# Lightning Module
# -------------------------------

class SegmentationModel(pl.LightningModule):
    def __init__(self, lr=1e-3):
        super().__init__()
        self.save_hyperparameters()
        self.model = smp.DeepLabV3Plus(
            encoder_name="resnext101_32x8d",
            encoder_weights="imagenet",
            in_channels=3,
            classes=1
        )

        self.dice = smp.losses.DiceLoss(mode='binary')
        self.bce = torch.nn.BCEWithLogitsLoss()
        self.metric = BinaryJaccardIndex()
        self.train_losses, self.val_losses = [], []
        self.train_ious, self.val_ious = [], []

    def forward(self, x):
        return self.model(x)

    def loss_fn(self, preds, targets):
        return self.dice(preds, targets) + self.bce(preds, targets)

    def training_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        loss = self.loss_fn(preds, y)
        iou = self.metric((torch.sigmoid(preds) > 0.5).int(), y.int())

        self.train_losses.append(loss.item())
        self.train_ious.append(iou.item())
        self.log('train_loss', loss)
        self.log('train_iou', iou, prog_bar=True)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        loss = self.loss_fn(preds, y)
        iou = self.metric((torch.sigmoid(preds) > 0.5).int(), y.int())

        self.val_losses.append(loss.item())
        self.val_ious.append(iou.item())
        self.log('val_loss', loss)
        self.log('val_iou', iou, prog_bar=True)
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.hparams.lr)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, mode='max', factor=0.5, patience=3)
        return {
            'optimizer': optimizer,
            'lr_scheduler': {
                'scheduler': scheduler,
                'monitor': 'val_iou',
                'interval': 'epoch',
                'frequency': 1
            }
        }

    def on_train_end(self):
        # Guardar curvas y métricas
        os.makedirs("G:\\jorge\\models\\DeepLabV3Plus-Resnext101_32x8d\\metrics", exist_ok=True)
        np.save("G:\\jorge\\models\\DeepLabV3Plus-Resnext101_32x8d\\metrics\\train_losses.npy", self.train_losses)
        np.save("G:\\jorge\\models\\DeepLabV3Plus-Resnext101_32x8d\\metrics\\val_losses.npy", self.val_losses)
        np.save("G:\\jorge\\models\\DeepLabV3Plus-Resnext101_32x8d\\metrics\\train_ious.npy", self.train_ious)
        np.save("G:\\jorge\\models\\DeepLabV3Plus-Resnext101_32x8d\\metrics\\val_ious.npy", self.val_ious)

        with open("G:\\jorge\\models\\DeepLabV3Plus-Resnext101_32x8d\\metrics\\metrics_summary.json", "w") as f:
            json.dump({
                "train_losses": self.train_losses,
                "val_losses": self.val_losses,
                "train_ious": self.train_ious,
                "val_ious": self.val_ious
            }, f)

        plt.figure(figsize=(12, 5))
        plt.subplot(1, 2, 1)
        plt.plot(self.train_losses, label='Train Loss')
        plt.plot(self.val_losses, label='Val Loss')
        plt.title("Loss")
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(self.train_ious, label='Train IoU')
        plt.plot(self.val_ious, label='Val IoU')
        plt.title("IoU")
        plt.legend()

        plt.tight_layout()
        plt.savefig("G:\\jorge\\models\\DeepLabV3Plus-Resnext101_32x8d\\metrics\\training_curves.png")
        plt.close()

    @staticmethod
    def load_from_checkpoint_custom(path, lr=1e-3):
        model = SegmentationModel.load_from_checkpoint(path, lr=lr)
        return model



# -------------------------------
# Configuración y entrenamiento
# -------------------------------

def main():
    use_checkpoint = False  # ← Cambia a False si quieres empezar de cero
    checkpoint_path = ""
    new_lr = 1e-3  # Puedes ajustarlo
    
    train_ds = INRIA_Dataset(
        image_dir='G:\\jorge\\Datasets\\images_512x512\\train\\train\\images',
        mask_dir='G:\\jorge\\Datasets\\images_512x512\\train\\train\\gt',
        transforms=get_train_transforms()
    )
    val_ds = INRIA_Dataset(
        image_dir='G:\\jorge\\Datasets\\images_512x512\\train\\val\\images',
        mask_dir='G:\\jorge\\Datasets\\images_512x512\\train\\val\\gt',
        transforms=get_val_transforms()
    )

    train_loader = DataLoader(train_ds, batch_size=8, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_ds, batch_size=8, shuffle=False, num_workers=0)

    if use_checkpoint:
        model = SegmentationModel.load_from_checkpoint_custom(checkpoint_path, lr=new_lr)
    else:
        model = SegmentationModel(lr=new_lr)

    callbacks = [
        EarlyStopping(monitor="val_iou", patience=5, mode="max"),
        ModelCheckpoint(
            dirpath="G:\\jorge\\models\\DeepLabV3Plus-Resnext101_32x8d\\checkpoints",
            filename="best_model_{epoch:02d}_{val_iou:.4f}",
            monitor="val_iou",
            save_top_k=1,
            mode="max",
        ),
        LearningRateMonitor(logging_interval='epoch')
    ]

    trainer = pl.Trainer(
        max_epochs=100,
        accelerator="gpu",
        devices=1,
        callbacks=callbacks,
        log_every_n_steps=10
    )

    trainer.fit(model, train_loader, val_loader)

if __name__ == "__main__":
    main()
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:albumentations.check_version:A new version of Albumentations is available: 2.0.5 (you have 1.4.10). Upgrade using: pip install --upgrade albumentations
# Downloading: "https://download.pytorch.org/models/resnext101_32x8d-8ba56ff5.pth" to C:\Users\jorge/.cache\torch\hub\checkpoints\resnext101_32x8d-8ba56ff5.pth
# 100%|███████████████████████████████████████████████████████████████████████████████| 340M/340M [00:31<00:00, 11.4MB/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name   | Type               | Params | Mode
# ------------------------------------------------------
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cambia según tu ruta
base_path = "G:\\jorge\\models\\DeepLabV3Plus-Resnext101_32x8d\\final_metrics\\"

# Cargar datos
train_losses = np.load(base_path + "train_losses.npy")
val_losses = np.load(base_path + "val_losses.npy")
train_ious = np.load(base_path + "train_ious.npy")
val_ious = np.load(base_path + "val_ious.npy")

# Número de épocas (ajústalo si hiciste menos/más)
num_epochs = 74

# Calcular tamaño del paso
steps_per_epoch_train = len(train_losses) // num_epochs
steps_per_epoch_val = len(val_losses) // num_epochs

# Agrupar y promediar
def average_per_epoch(array, steps_per_epoch):
    return np.mean(array[:steps_per_epoch*num_epochs].reshape(num_epochs, steps_per_epoch), axis=1)

train_loss_avg = average_per_epoch(train_losses, steps_per_epoch_train)
val_loss_avg = average_per_epoch(val_losses, steps_per_epoch_val)
train_iou_avg = average_per_epoch(train_ious, steps_per_epoch_train)
val_iou_avg = average_per_epoch(val_ious, steps_per_epoch_val)

# Graficar
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss_avg, label="Train Loss")
plt.plot(val_loss_avg, label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss por época")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_iou_avg, label="Train IoU")
plt.plot(val_iou_avg, label="Val IoU")
plt.xlabel("Epoch")
plt.ylabel("IoU")
plt.title("IoU por época")
plt.legend()

plt.tight_layout()
plt.savefig(base_path + "training_curves_epoch_avg.png")
plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import cv2
from torchvision.utils import make_grid
import os

checkpoint_path = "G:\\jorge\\models\\DeepLabV3Plus-Resnext101_32x8d\\final_checkpoints\\best_model_epoch=68_val_iou=0.7853.ckpt"

def visualize_predictions(model, dataset, device='cuda', num_samples=5, save_dir=None):
    model.eval()
    model.to(device)

    indices = np.random.choice(len(dataset), num_samples, replace=False)
    ious = []

    if save_dir:
        os.makedirs(save_dir, exist_ok=True)

    for i, idx in enumerate(indices):
        image, gt_mask = dataset[idx]
        image_tensor = image.unsqueeze(0).to(device)  # (1, 3, H, W)
        with torch.no_grad():
            pred = model(image_tensor)
            pred = torch.sigmoid(pred).squeeze().cpu().numpy()
            pred_mask = (pred > 0.5).astype(np.uint8)

        gt_mask_np = gt_mask.squeeze().cpu().numpy().astype(np.uint8)
        image_np = image.permute(1, 2, 0).cpu().numpy()
        image_np = (image_np * [0.229, 0.224, 0.225] + [0.485, 0.456, 0.406])  # Unnormalize
        image_np = np.clip(image_np * 255, 0, 255).astype(np.uint8)

        # IoU
        intersection = np.logical_and(pred_mask, gt_mask_np).sum()
        union = np.logical_or(pred_mask, gt_mask_np).sum()
        iou = intersection / union if union != 0 else 0.0
        ious.append(iou)

        # Overlay
        overlay = image_np.copy()
        overlay[gt_mask_np == 1] = [0, 255, 0]  # Ground Truth: verde
        overlay[pred_mask == 1] = [255, 0, 0]   # Pred: rojo
        overlay[(gt_mask_np == 1) & (pred_mask == 1)] = [255, 255, 0]  # Ambos: amarillo

        # Error Map
        error_map = np.zeros_like(image_np)
        error_map[(gt_mask_np == 1) & (pred_mask == 0)] = [0, 0, 255]      # Falsos negativos: azul
        error_map[(gt_mask_np == 0) & (pred_mask == 1)] = [255, 0, 0]      # Falsos positivos: rojo
        error_map[(gt_mask_np == 1) & (pred_mask == 1)] = [0, 255, 0]      # Verdaderos positivos: verde

        # Plot
        fig, axes = plt.subplots(1, 5, figsize=(20, 5))
        titles = ["Imagen", "GT", "Pred", "Overlay", "Error Map"]
        images = [image_np,
                  (gt_mask_np * 255).astype(np.uint8),
                  (pred_mask * 255).astype(np.uint8),
                  overlay,
                  error_map]

        for ax, img, title in zip(axes, images, titles):
            ax.imshow(img if img.ndim == 3 else img, cmap='gray')
            ax.set_title(title)
            ax.axis('off')

        fig.suptitle(f"IoU: {iou:.4f}")
        if save_dir:
            plt.savefig(os.path.join(save_dir, f"sample_{i}_iou_{iou:.4f}.png"))
        plt.show()

    return ious
    
def plot_iou_histogram(ious, save_path=None):
    plt.figure(figsize=(8, 4))
    plt.hist(ious, bins=10, range=(0, 1), color='skyblue', edgecolor='black')
    plt.title("Distribución de IoU por imagen")
    plt.xlabel("IoU")
    plt.ylabel("Frecuencia")
    plt.grid(True)
    if save_path:
        plt.savefig(save_path)
    plt.show()

# Asegúrate de tener el modelo cargado
model = SegmentationModel.load_from_checkpoint_custom(checkpoint_path, lr=1e-3)
val_dataset = INRIA_Dataset(
    image_dir='G:\\jorge\\Datasets\\images_512x512\\train\\val\\images',
    mask_dir='G:\\jorge\\Datasets\\images_512x512\\train\\val\\gt',
    transforms=get_val_transforms()
)

# Mostrar predicciones y errores
ious = visualize_predictions(model, val_dataset, num_samples=8, save_dir="G:\\jorge\\models\\DeepLabV3Plus-Resnext101_32x8d\\visualizations")

# Histograma de IoUs
plot_iou_histogram(ious, save_path="G:\\jorge\\models\\DeepLabV3Plus-Resnext101_32x8d\\visualizations\\iou_hist.png")
